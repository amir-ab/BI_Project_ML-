# %% [markdown]
# <a href="https://colab.research.google.com/github/amir-ab/BI_Project_ML-/blob/main/CAH_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import des données
import pandas as pd
import numpy as np
from random import uniform
from sklearn import cluster

from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
# %matplotlib inline

import plotly.figure_factory as ff
import numpy as np

# %%
#dataset1= pd.read_table("/content/project",sep="\t",header=0,index_col=0)
dataset = pd.read_csv('/content/project', sep="\t",)
dataset
# Out:
#      project_id  projectcode  ...  validatedCost       ClientName
# 0             1            1  ...            NaN  Client Talys 13
# 1             2            2  ...            NaN  Client Talys 15
# 2             3            3  ...            NaN   Client Talys 9
# 3             4            4  ...            NaN   Client Talys 7
# 4             5            5  ...            NaN   Client Talys 6
# ..          ...          ...  ...            ...              ...
# 96           97           99  ...            NaN  Client Talys 32
# 97           98          100  ...            NaN  Client Talys 32
# 98           99          101  ...            NaN  Client Talys 46
# 99          100          102  ...            NaN  Client Talys 57
# 100         101          103  ...            NaN              NaN
#
# [101 rows x 10 columns]

# %%
dataset.dropna(subset = ["ClientName"], inplace=True)
df = df.fillna(0)

# %%
#statistiques descriptives
#print(dataset.describe())
df.describe()
# Out:
#        project_id  projectcode  ...  totalLeftCost   validatedCost
# count   72.000000    72.000000  ...           72.0            72.0
# mean    55.750000    56.972222  ...            0.0             0.0
# std     29.946313    30.784106  ...            0.0             0.0
# min      1.000000     1.000000  ...            0.0             0.0
# 25%     38.750000    38.750000  ...            0.0             0.0
# 50%     60.500000    62.500000  ...            0.0             0.0
# 75%     79.250000    81.250000  ...            0.0             0.0
# max    100.000000   102.000000  ...            0.0             0.0
#
# [8 rows x 8 columns]

# %%
d = df.drop(['projectname','ClientName'],1,errors="ignore")
d
# Out:
#              project_id  projectcode  ...  totalLeftCost   validatedCost
# projectname                           ...
# Project 1             1            1  ...            0.0             0.0
# Project 2             2            2  ...            0.0             0.0
# Project 3             3            3  ...            0.0             0.0
# Project 4             4            4  ...            0.0             0.0
# Project 5             5            5  ...            0.0             0.0
# ...                 ...          ...  ...            ...             ...
# Project 98           96           98  ...            0.0             0.0
# Project 99           97           99  ...            0.0             0.0
# Project 100          98          100  ...            0.0             0.0
# Project 101          99          101  ...            0.0             0.0
# Project 102         100          102  ...            0.0             0.0
#
# [72 rows x 8 columns]

# %%
km = KMeans (n_clusters=3)
km
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
#générer la matrice des liens
Z = linkage(d,method='ward',metric='euclidean')

#affichage du dendrogramme
#plt.title("CAH")
#dendrogram(Z,labels=fromage.index,orientation='left',color_threshold=0)
#plt.show()


fig = ff.create_dendrogram(Z, labels=d.index,orientation='left')
fig.update_layout(width=1000, height=1000)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="16f57df9-83b0-4ba4-ae22-8411e70e14ef" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("16f57df9-83b0-4ba4-ae22-8411e70e14ef")) {
#                     Plotly.newPlot(
#                         '16f57df9-83b0-4ba4-ae22-8411e70e14ef',
# ...
